# %% [markdown]
#     Name - Vaibhav Dwivedi
#     Roll No. - 2020BTechCSE097
#     Section - B

# %% [markdown]
# ## Q1

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1) 
a=1
s=0
t=0

plt.figure(figsize=(31,12))
t=0
s=((3*np.sin(np.pi*x) *np.cos(np.pi*t))- (np.sin(3*np.pi*x)*np.cos(3*np.pi*t)))/4
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=((3*np.sin(np.pi*x) *np.cos(np.pi*t))- (np.sin(3*np.pi*x)*np.cos(3*np.pi*t)))/4
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=((3*np.sin(np.pi*x) *np.cos(np.pi*t))- (np.sin(3*np.pi*x)*np.cos(3*np.pi*t)))/4
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=((3*np.sin(np.pi*x) *np.cos(np.pi*t))- (np.sin(3*np.pi*x)*np.cos(3*np.pi*t)))/4
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=((3*np.sin(np.pi*x) *np.cos(np.pi*t))- (np.sin(3*np.pi*x)*np.cos(3*np.pi*t)))/4
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q2

# %%
import math 
import matplotlib.pyplot as plt 
import numpy as np 

x = np.linspace(0,1)


t=0
    

plt.figure(figsize=(31,12))
s=0

t=0
for n in range (1,101,2):

    w=8*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()

s=0

t=0.2
for n in range (1,101,2):

    w=8*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()

s=0

t=1
for n in range (1,101,2):

    w=8*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()

s=0

t=2
for n in range (1,101,2):

    w=8*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

s=0

t=5
for n in range (1,101,2):

    w=8*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - i

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

X = np.linspace(0,1)

a=1

K = 0.01


plt.figure(figsize=(31,12))
t=0
s= K*np.sin(3*np.pi*x)*np.cos(3*np.pi*t)
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=K*np.sin(3*np.pi*x)*np.cos(3*np.pi*t)
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=K*np.sin(3*np.pi*x)*np.cos(3*np.pi*t)
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=K*np.sin(3*np.pi*x)*np.cos(3*np.pi*t)
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=K*np.sin(3*np.pi*x)*np.cos(3*np.pi*t)
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - ii

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x = np.linspace(0,1)

K = 0.01


plt.figure(figsize=(31,12))
t=0
s= K*(np.cos(np.pi*t)*np.sin(np.pi*x) - (np.cos(2*np.pi*t)*np.sin(2*np.pi*x))/2)
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s= K*(np.cos(np.pi*t)*np.sin(np.pi*x) - (np.cos(2*np.pi*t)*np.sin(2*np.pi*x))/2)
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s= K*(np.cos(np.pi*t)*np.sin(np.pi*x) - (np.cos(2*np.pi*t)*np.sin(2*np.pi*x))/2)
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s= K*(np.cos(np.pi*t)*np.sin(np.pi*x) - (np.cos(2*np.pi*t)*np.sin(2*np.pi*x))/2)
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s= K*(np.cos(np.pi*t)*np.sin(np.pi*x) - (np.cos(2*np.pi*t)*np.sin(2*np.pi*x))/2)
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - iii

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x = np.linspace(0,1)

s=0

k = 0.01

plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,101,2):

    w=8*k*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()

s=0
t=0.2
for n in range (1,101,2):

    w=8*k*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()

s=0
t=1
for n in range (1,101,2):

    w=8*k*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()

s=0
t=2
for n in range (1,101,2):

    w=8*k*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()
s=0
t=5
for n in range (1,101,2):

    w=8*k*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - iv

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x = np.linspace(0,1) 



k = 0.01
 
plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,101,):

    w=4*k*((-2*(-1)**n)-1)*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range (1,101,):

    w=4*k*((-2*(-1)**n)-1)*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range (1,101,):

    w=4*k*((-2*(-1)**n)-1)*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range (1,101,):

    w=4*k*((-2*(-1)**n)-1)*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range (1,101,):

    w=4*k*((-2*(-1)**n)-1)*np.sin(n*np.pi*x)*np.cos(n*np.pi*t)/(n*np.pi)**3

    s=s+w
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - v

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x= np.arange (0,1,0.001) 
s=0

t=0
 
plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,101):



    w=(4*np.sin((n*np.pi)/2)*(np.sin(n*np.pi*x))*(np.cos(n*np.pi*t)))/(5*n*n*np.pi*np.pi)
    s=s+w

plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range (1,101):



    w=(4*np.sin((n*np.pi)/2)*(np.sin(n*np.pi*x))*(np.cos(n*np.pi*t)))/(5*n*n*np.pi*np.pi)
    s=s+w

plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range (1,101):



    w=(4*np.sin((n*np.pi)/2)*(np.sin(n*np.pi*x))*(np.cos(n*np.pi*t)))/(5*n*n*np.pi*np.pi)
    s=s+w

plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range (1,101):



    w=(4*np.sin((n*np.pi)/2)*(np.sin(n*np.pi*x))*(np.cos(n*np.pi*t)))/(5*n*n*np.pi*np.pi)
    s=s+w

plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range (1,101):



    w=(4*np.sin((n*np.pi)/2)*(np.sin(n*np.pi*x))*(np.cos(n*np.pi*t)))/(5*n*n*np.pi*np.pi)
    s=s+w

plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - vi

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

X = np.linspace(0,1)
s=0
t=0
 
plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,101):

    w=4*((np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range (1,101):

    w=4*((np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range (1,101):

    w=4*((np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range (1,101):

    w=4*((np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range (1,101):

    w=4*((np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - vii

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x= np.arange(0,1,0.001)
s=0
t=0
 
plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,100):

    w=((2/(n**2*np.pi**2))*(2*np.sin(n*np.pi/2) - np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))

    s=s+w

plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range (1,100):

    w=((2/(n**2*np.pi**2))*(2*np.sin(n*np.pi/2) - np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))

    s=s+w

plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range (1,100):

    w=((2/(n**2*np.pi**2))*(2*np.sin(n*np.pi/2) - np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))

    s=s+w

plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range (1,100):

    w=((2/(n**2*np.pi**2))*(2*np.sin(n*np.pi/2) - np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))

    s=s+w

plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range (1,100):

    w=((2/(n**2*np.pi**2))*(2*np.sin(n*np.pi/2) - np.sin(n*np.pi/4) - np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))

    s=s+w

plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - viii

# %%
import math

import matplotlib.pyplot as plt

import numpy as np

x= np.arange (0,1,0.001)
s=0
t=0
    
plt.figure(figsize=(31,12))
t=0
s=0
for n in range (1,101):

    w=2*((np.sin(n*np.pi/4) + np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range (1,101):

    w=2*((np.sin(n*np.pi/4) + np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range (1,101):

    w=2*((np.sin(n*np.pi/4) + np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range (1,101):

    w=2*((np.sin(n*np.pi/4) + np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w

plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range (1,101):

    w=2*((np.sin(n*np.pi/4) + np.sin(3*n*np.pi/4))*np.sin(n*np.pi*x)*np.cos(n*np.pi*t))/((np.pi*n)**2)

    s=s+w
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()

# %% [markdown]
# ## Q3 - ix

# %%
import math 
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,1) 
s=0
t=1    
    
plt.figure(figsize=(31,12))
t=0
s=0
for n in range(1,101):
    w=4*((-3*np.sin(n*np.pi/2) - (4*np.cos(n*np.pi/2))/(n*np.pi) + 4/(n*np.pi))*np.cos(n*np.pi*t)*np.sin(n*np.pi*x))/((np.pi*n)**2)
    s=s+w

plt.subplot(2,3,1)
plt.title("t = 0",size = "25")
plt.plot (x, s)
plt.grid()


t=0.2
s=0
for n in range(1,101):
    w=4*((-3*np.sin(n*np.pi/2) - (4*np.cos(n*np.pi/2))/(n*np.pi) + 4/(n*np.pi))*np.cos(n*np.pi*t)*np.sin(n*np.pi*x))/((np.pi*n)**2)
    s=s+w

plt.subplot(2,3,2)
plt.title("t = 0.2",size = "25")
plt.plot (x, s)
plt.grid()


t=1
s=0
for n in range(1,101):
    w=4*((-3*np.sin(n*np.pi/2) - (4*np.cos(n*np.pi/2))/(n*np.pi) + 4/(n*np.pi))*np.cos(n*np.pi*t)*np.sin(n*np.pi*x))/((np.pi*n)**2)
    s=s+w

plt.subplot(2,3,3)
plt.title("t = 1",size = "25")
plt.plot (x, s)
plt.grid()


t=2
s=0
for n in range(1,101):
    w=4*((-3*np.sin(n*np.pi/2) - (4*np.cos(n*np.pi/2))/(n*np.pi) + 4/(n*np.pi))*np.cos(n*np.pi*t)*np.sin(n*np.pi*x))/((np.pi*n)**2)
    s=s+w

plt.subplot(2,3,4)
plt.plot (x, s)
plt.title("t = 2",size = "25")
plt.grid()

t=5
s=0
for n in range(1,101):
    w=4*((-3*np.sin(n*np.pi/2) - (4*np.cos(n*np.pi/2))/(n*np.pi) + 4/(n*np.pi))*np.cos(n*np.pi*t)*np.sin(n*np.pi*x))/((np.pi*n)**2)
    s=s+w
plt.subplot(2,3,5)
plt.plot (x, s)
plt.title("t = 5",size = "25")
plt.grid()

plt.show()
